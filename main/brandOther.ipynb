# %%
import sys
sys.path.append('..')

from utilities import *

warnings.filterwarnings('ignore')


raw_data = pd.read_excel("../data/Datos_Market_copy.xlsx")

sa = SalesAnalysis(raw_data)

data = sa.data[sa.brandOther]

train_data, test_data = sa.divide_data_for_train_and_test(data)

# %%
model, design_info, selected_columns = sa.modelization_with_backward_elimination(train_data)
X_train_exog = sa.x_train_exog(train_data, selected_columns, model)
# Out:
# ✅ YES - All features match perfectly!

# %%
# Now we can run auto_arima with the correct exogenous variables
auto_arima_model = auto_arima( 
    y=train_data['volume.sales'],
    X=X_train_exog,  # Use the properly formatted exogenous variables
    start_p=0,
    d=1,  
    start_q=0,
    max_p=3, 
    max_q=3,
    start_P=0,
    D=1,  # Set seasonal differencing explicitly
    start_Q=0,
    max_P=1, 
    max_Q=1,
    m=12,  # Monthly data
    seasonal=True,
    trace=True,
    error_action="warn",  # Change to warn to see potential issues
    suppress_warnings=True,
    stepwise=True,
    random_state=42,
    n_fits=50,
    information_criterion='aic'
)

print("Auto ARIMA model fitted successfully!")
print(auto_arima_model.summary())
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(0,1,0)(0,1,0)[12]             : AIC=19715.768, Time=0.45 sec
#  ARIMA(1,1,0)(1,1,0)[12]             : AIC=15402.596, Time=20.30 sec
#  ARIMA(0,1,1)(0,1,1)[12]             : AIC=inf, Time=124.44 sec
#  ARIMA(1,1,0)(0,1,0)[12]             : AIC=15548.480, Time=0.52 sec
#  ARIMA(1,1,0)(1,1,1)[12]             : AIC=inf, Time=123.89 sec
#  ARIMA(1,1,0)(0,1,1)[12]             : AIC=inf, Time=101.19 sec
#  ARIMA(0,1,0)(1,1,0)[12]             : AIC=15588.175, Time=13.40 sec
#  ARIMA(2,1,0)(1,1,0)[12]             : AIC=15345.638, Time=27.33 sec
#  ARIMA(2,1,0)(0,1,0)[12]             : AIC=15486.019, Time=1.16 sec
#  ARIMA(2,1,0)(1,1,1)[12]             : AIC=inf, Time=164.00 sec
#  ARIMA(2,1,0)(0,1,1)[12]             : AIC=inf, Time=149.33 sec
#  ARIMA(3,1,0)(1,1,0)[12]             : AIC=15317.026, Time=32.97 sec
#  ARIMA(3,1,0)(0,1,0)[12]             : AIC=15458.664, Time=2.37 sec
#  ARIMA(3,1,0)(1,1,1)[12]             : AIC=inf, Time=65.61 sec
#  ARIMA(3,1,0)(0,1,1)[12]             : AIC=inf, Time=51.52 sec
#  ARIMA(3,1,1)(1,1,0)[12]             : AIC=15242.458, Time=80.65 sec
#  ARIMA(3,1,1)(0,1,0)[12]             : AIC=inf, Time=8.72 sec
#  ARIMA(3,1,1)(1,1,1)[12]             : AIC=inf, Time=93.77 sec
#  ARIMA(3,1,1)(0,1,1)[12]             : AIC=inf, Time=229.75 sec
#  ARIMA(2,1,1)(1,1,0)[12]             : AIC=15240.571, Time=62.70 sec
#  ARIMA(2,1,1)(0,1,0)[12]             : AIC=inf, Time=4.98 sec
#  ARIMA(2,1,1)(1,1,1)[12]             : AIC=inf, Time=89.38 sec
#  ARIMA(2,1,1)(0,1,1)[12]             : AIC=inf, Time=148.10 sec
#  ARIMA(1,1,1)(1,1,0)[12]             : AIC=15240.040, Time=45.95 sec
#  ARIMA(1,1,1)(0,1,0)[12]             : AIC=inf, Time=10.78 sec
#  ARIMA(1,1,1)(1,1,1)[12]             : AIC=inf, Time=219.06 sec
#  ARIMA(1,1,1)(0,1,1)[12]             : AIC=inf, Time=227.30 sec
#  ARIMA(0,1,1)(1,1,0)[12]             : AIC=15184.676, Time=92.14 sec
#  ARIMA(0,1,1)(0,1,0)[12]             : AIC=inf, Time=4.37 sec
#  ARIMA(0,1,1)(1,1,1)[12]             : AIC=inf, Time=128.42 sec
#  ARIMA(0,1,2)(1,1,0)[12]             : AIC=15223.495, Time=35.06 sec
#  ARIMA(1,1,2)(1,1,0)[12]             : AIC=15224.131, Time=35.06 sec
#  ARIMA(0,1,1)(1,1,0)[12] intercept   : AIC=15185.416, Time=159.51 sec
#
# Best model:  ARIMA(0,1,1)(1,1,0)[12]
# Total fit time: 2554.545 seconds
# Auto ARIMA model fitted successfully!
#                                       SARIMAX Results
# ===========================================================================================
# Dep. Variable:                                   y   No. Observations:                  722
# Model:             SARIMAX(0, 1, 1)x(1, 1, [], 12)   Log Likelihood               -7543.338
# Date:                             Tue, 18 Nov 2025   AIC                          15184.676
# Time:                                     01:40:58   BIC                          15408.305
# Sample:                                          0   HQIC                         15271.071
#                                              - 722
# Covariance Type:                               opg
# =================================================================================================================================
#                                                                     coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------------------------------------
# C(supermarket)[T.supermarket-B]                               -1.357e+04   4370.490     -3.105      0.002   -2.21e+04   -5005.038
# C(supermarket)[T.supermarket-D]                                 5.43e+04   3933.199     13.807      0.000    4.66e+04     6.2e+04
# C(variant)[T.light]                                           -1.633e+05   1.92e+04     -8.501      0.000   -2.01e+05   -1.26e+05
# C(variant)[T.standard]                                        -9.383e+04   4462.649    -21.025      0.000   -1.03e+05   -8.51e+04
# C(variant)[T.vegan]                                           -2.454e+04   2750.408     -8.922      0.000   -2.99e+04   -1.91e+04
# C(pack_size)[T.351 - 500 GR]                                   5.483e+04   3710.987     14.775      0.000    4.76e+04    6.21e+04
# C(pack_size)[T.450 - 600GR]                                    1.101e+04   3296.384      3.340      0.001    4549.640    1.75e+04
# C(pack_size)[T.501 - 700 GR]                                   2.805e+04   6463.720      4.340      0.000    1.54e+04    4.07e+04
# C(pack_size)[T.701 - 1000 GR]                                 -1.265e+04   3614.181     -3.500      0.000   -1.97e+04   -5566.113
# C(supermarket)[T.supermarket-B]:C(variant)[T.light]            6.189e+04   3791.348     16.324      0.000    5.45e+04    6.93e+04
# C(supermarket)[T.supermarket-C]:C(variant)[T.light]             2.25e+04   3708.197      6.068      0.000    1.52e+04    2.98e+04
# C(supermarket)[T.supermarket-D]:C(variant)[T.light]            8.067e+04   9510.038      8.483      0.000     6.2e+04    9.93e+04
# C(supermarket)[T.supermarket-B]:C(variant)[T.standard]         4.702e+04   2452.191     19.174      0.000    4.22e+04    5.18e+04
# C(supermarket)[T.supermarket-C]:C(variant)[T.standard]         2.293e+04   3148.386      7.284      0.000    1.68e+04    2.91e+04
# C(supermarket)[T.supermarket-D]:C(variant)[T.standard]         5329.8811   2200.239      2.422      0.015    1017.491    9642.271
# C(supermarket)[T.supermarket-B]:C(variant)[T.vegan]            1.099e+04   4207.250      2.612      0.009    2741.315    1.92e+04
# C(supermarket)[T.supermarket-D]:C(variant)[T.vegan]           -1.985e+04   3929.582     -5.051      0.000   -2.76e+04   -1.21e+04
# C(supermarket)[T.supermarket-B]:C(pack_size)[T.351 - 500 GR]  -3.406e+04   2374.505    -14.345      0.000   -3.87e+04   -2.94e+04
# C(supermarket)[T.supermarket-C]:C(pack_size)[T.351 - 500 GR]  -2.174e+04   3374.295     -6.444      0.000   -2.84e+04   -1.51e+04
# C(supermarket)[T.supermarket-D]:C(pack_size)[T.351 - 500 GR]  -3.247e+04   2341.880    -13.863      0.000   -3.71e+04   -2.79e+04
# C(supermarket)[T.supermarket-B]:C(pack_size)[T.450 - 600GR]    1.101e+04   3296.384      3.340      0.001    4549.640    1.75e+04
# C(supermarket)[T.supermarket-C]:C(pack_size)[T.450 - 600GR]   -4.279e-12   1.38e+05   -3.1e-17      1.000   -2.71e+05    2.71e+05
# C(supermarket)[T.supermarket-D]:C(pack_size)[T.450 - 600GR]    9.042e-11   1.38e+05   6.54e-16      1.000   -2.71e+05    2.71e+05
# C(supermarket)[T.supermarket-B]:C(pack_size)[T.501 - 700 GR]   5.897e-11   1.38e+05   4.27e-16      1.000   -2.71e+05    2.71e+05
# C(supermarket)[T.supermarket-C]:C(pack_size)[T.501 - 700 GR]  -1.472e-10   1.38e+05  -1.07e-15      1.000   -2.71e+05    2.71e+05
# C(supermarket)[T.supermarket-C]:C(pack_size)[T.701 - 1000 GR]   2.25e+04   3708.197      6.068      0.000    1.52e+04    2.98e+04
# C(supermarket)[T.supermarket-D]:C(pack_size)[T.701 - 1000 GR] -4.185e+04   4720.851     -8.864      0.000   -5.11e+04   -3.26e+04
# C(variant)[T.light]:C(pack_size)[T.351 - 500 GR]               8.777e+04   1.89e+04      4.634      0.000    5.06e+04    1.25e+05
# C(variant)[T.standard]:C(pack_size)[T.351 - 500 GR]            7278.9743   1811.106      4.019      0.000    3729.271    1.08e+04
# C(variant)[T.vegan]:C(pack_size)[T.351 - 500 GR]               1.768e-11   1.38e+05   1.28e-16      1.000   -2.71e+05    2.71e+05
# C(variant)[T.light]:C(pack_size)[T.450 - 600GR]               -2.817e-12   1.38e+05  -2.04e-17      1.000   -2.71e+05    2.71e+05
# C(variant)[T.standard]:C(pack_size)[T.450 - 600GR]             1.101e+04   3296.384      3.340      0.001    4549.640    1.75e+04
# C(variant)[T.light]:C(pack_size)[T.501 - 700 GR]                       0   1.38e+05          0      1.000   -2.71e+05    2.71e+05
# C(variant)[T.standard]:C(pack_size)[T.501 - 700 GR]            2.805e+04   6463.720      4.340      0.000    1.54e+04    4.07e+04
# C(variant)[T.vegan]:C(pack_size)[T.501 - 700 GR]                       0   1.38e+05          0      1.000   -2.71e+05    2.71e+05
# C(variant)[T.light]:C(pack_size)[T.701 - 1000 GR]              1.004e+05   1.73e+04      5.813      0.000    6.65e+04    1.34e+05
# C(variant)[T.standard]:C(pack_size)[T.701 - 1000 GR]                   0   1.38e+05          0      1.000   -2.71e+05    2.71e+05
# C(variant)[T.vegan]:C(pack_size)[T.701 - 1000 GR]                      0   1.38e+05          0      1.000   -2.71e+05    2.71e+05
# price                                                           1.16e+04   1865.236      6.219      0.000    7944.940    1.53e+04
# price:C(supermarket)[T.supermarket-B]                         -1.141e+04   2487.104     -4.587      0.000   -1.63e+04   -6532.758
# price:C(supermarket)[T.supermarket-C]                         -1.132e+04   1188.293     -9.524      0.000   -1.36e+04   -8987.821
# price:C(supermarket)[T.supermarket-D]                         -2.377e+04   2107.269    -11.279      0.000   -2.79e+04   -1.96e+04
# price:C(variant)[T.standard]                                   2.096e+04   2540.853      8.250      0.000     1.6e+04    2.59e+04
# price:C(pack_size)[T.351 - 500 GR]                            -1.618e+04   2066.674     -7.827      0.000   -2.02e+04   -1.21e+04
# price:C(pack_size)[T.450 - 600GR]                             -1.646e+04   9100.421     -1.809      0.070   -3.43e+04    1373.538
# price:C(pack_size)[T.501 - 700 GR]                            -2.643e+04   6199.925     -4.263      0.000   -3.86e+04   -1.43e+04
# ma.L1                                                            -0.8978      0.021    -42.610      0.000      -0.939      -0.856
# ar.S.L12                                                         -0.4648      0.024    -19.241      0.000      -0.512      -0.417
# sigma2                                                         1.034e+08   5026.161   2.06e+04      0.000    1.03e+08    1.03e+08
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.05   Jarque-Bera (JB):              1216.63
# Prob(Q):                              0.82   Prob(JB):                         0.00
# Heteroskedasticity (H):               2.11   Skew:                             0.68
# Prob(H) (two-sided):                  0.00   Kurtosis:                         9.27
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 3.42e+33. Standard errors may be unstable.
