# %%
import sys
sys.path.append('..')

from utilities import *

warnings.filterwarnings('ignore')


raw_data = pd.read_excel("../data/Datos_Market_copy.xlsx")

sa = SalesAnalysis(raw_data)

data = sa.data[sa.brand15]

train_data, test_data = sa.divide_data_for_train_and_test(data)

# %%
model, design_info, selected_columns = sa.modelization_with_backward_elimination(train_data)
X_train_exog = sa.x_train_exog(train_data, selected_columns, model)
# Out:
# ✅ YES - All features match perfectly!

# %%
# Now we can run auto_arima with the correct exogenous variables
auto_arima_model = auto_arima( 
    y=train_data['volume.sales'],
    X=X_train_exog,  # Use the properly formatted exogenous variables
    start_p=0,
    d=1,  
    start_q=0,
    max_p=3, 
    max_q=3,
    start_P=0,
    D=1,  # Set seasonal differencing explicitly
    start_Q=0,
    max_P=1, 
    max_Q=1,
    m=12,  # Monthly data
    seasonal=True,
    trace=True,
    error_action="warn",  # Change to warn to see potential issues
    suppress_warnings=True,
    stepwise=True,
    random_state=42,
    n_fits=50,
    information_criterion='aic'
)

print("Auto ARIMA model fitted successfully!")
print(auto_arima_model.summary())
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(0,1,0)(0,1,0)[12]             : AIC=33199.843, Time=0.43 sec
#  ARIMA(1,1,0)(1,1,0)[12]             : AIC=26063.398, Time=10.98 sec
#  ARIMA(0,1,1)(0,1,1)[12]             : AIC=inf, Time=87.80 sec
#  ARIMA(1,1,0)(0,1,0)[12]             : AIC=26313.347, Time=0.65 sec
#  ARIMA(1,1,0)(1,1,1)[12]             : AIC=inf, Time=24.92 sec
#  ARIMA(1,1,0)(0,1,1)[12]             : AIC=inf, Time=53.25 sec
#  ARIMA(0,1,0)(1,1,0)[12]             : AIC=26349.860, Time=8.58 sec
#  ARIMA(2,1,0)(1,1,0)[12]             : AIC=25917.572, Time=14.68 sec
#  ARIMA(2,1,0)(0,1,0)[12]             : AIC=26173.154, Time=0.99 sec
#  ARIMA(2,1,0)(1,1,1)[12]             : AIC=inf, Time=32.64 sec
#  ARIMA(2,1,0)(0,1,1)[12]             : AIC=inf, Time=30.74 sec
#  ARIMA(3,1,0)(1,1,0)[12]             : AIC=25860.157, Time=21.12 sec
#  ARIMA(3,1,0)(0,1,0)[12]             : AIC=26121.941, Time=1.69 sec
#  ARIMA(3,1,0)(1,1,1)[12]             : AIC=inf, Time=42.08 sec
#  ARIMA(3,1,0)(0,1,1)[12]             : AIC=inf, Time=38.45 sec
#  ARIMA(3,1,1)(1,1,0)[12]             : AIC=inf, Time=81.41 sec
#  ARIMA(2,1,1)(1,1,0)[12]             : AIC=inf, Time=72.27 sec
#  ARIMA(3,1,0)(1,1,0)[12] intercept   : AIC=25862.163, Time=20.73 sec
#
# Best model:  ARIMA(3,1,0)(1,1,0)[12]
# Total fit time: 543.533 seconds
# Auto ARIMA model fitted successfully!
#                                      SARIMAX Results
# ==========================================================================================
# Dep. Variable:                                  y   No. Observations:                 1107
# Model:             SARIMAX(3, 1, 0)x(1, 1, 0, 12)   Log Likelihood              -12900.079
# Date:                            Tue, 18 Nov 2025   AIC                          25860.157
# Time:                                    00:58:02   BIC                          26010.085
# Sample:                                         0   HQIC                         25916.891
#                                            - 1107
# Covariance Type:                              opg
# =================================================================================================================================
#                                                                     coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------------------------------------
# C(variant)[T.light]                                            2.878e+04   8122.942      3.544      0.000    1.29e+04    4.47e+04
# C(variant)[T.standard]                                         4.833e+04   8268.482      5.846      0.000    3.21e+04    6.45e+04
# C(variant)[T.vegan]                                            1.165e+04   5414.416      2.153      0.031    1042.844    2.23e+04
# C(pack_size)[T.701 - 1000 GR]                                  3.059e+05   1.38e+04     22.185      0.000    2.79e+05    3.33e+05
# C(supermarket)[T.supermarket-B]:C(variant)[T.standard]          -1.1e+04   5362.887     -2.052      0.040   -2.15e+04    -493.008
# C(supermarket)[T.supermarket-D]:C(variant)[T.standard]         4.708e+04   4556.714     10.331      0.000    3.81e+04     5.6e+04
# C(supermarket)[T.supermarket-C]:C(variant)[T.vegan]           -1.819e+04   8273.971     -2.198      0.028   -3.44e+04   -1972.188
# C(supermarket)[T.supermarket-D]:C(variant)[T.vegan]           -1.147e+04   6192.634     -1.851      0.064   -2.36e+04     672.207
# C(supermarket)[T.supermarket-C]:C(pack_size)[T.351 - 500 GR]   3.394e+04   7387.547      4.594      0.000    1.95e+04    4.84e+04
# C(supermarket)[T.supermarket-D]:C(pack_size)[T.351 - 500 GR]   4.817e+04   4692.076     10.266      0.000     3.9e+04    5.74e+04
# C(supermarket)[T.supermarket-C]:C(pack_size)[T.501 - 700 GR]  -3.115e+04   1.18e+04     -2.644      0.008   -5.42e+04   -8063.329
# C(supermarket)[T.supermarket-D]:C(pack_size)[T.501 - 700 GR]  -4.162e+04   6006.076     -6.930      0.000   -5.34e+04   -2.98e+04
# C(supermarket)[T.supermarket-B]:C(pack_size)[T.701 - 1000 GR] -6.493e+04   6324.860    -10.266      0.000   -7.73e+04   -5.25e+04
# C(supermarket)[T.supermarket-C]:C(pack_size)[T.701 - 1000 GR] -2.362e+04   1.01e+04     -2.336      0.020   -4.34e+04   -3799.852
# C(supermarket)[T.supermarket-D]:C(pack_size)[T.701 - 1000 GR]  8.805e+04   5543.935     15.882      0.000    7.72e+04    9.89e+04
# C(variant)[T.light]:C(pack_size)[T.351 - 500 GR]               6.971e+04   7805.785      8.930      0.000    5.44e+04     8.5e+04
# C(variant)[T.standard]:C(pack_size)[T.351 - 500 GR]            1.077e+05   5992.355     17.976      0.000     9.6e+04    1.19e+05
# C(variant)[T.light]:C(pack_size)[T.501 - 700 GR]              -4518.8607   9035.973     -0.500      0.617   -2.22e+04    1.32e+04
# C(variant)[T.light]:C(pack_size)[T.701 - 1000 GR]             -1.051e+05   9298.418    -11.299      0.000   -1.23e+05   -8.68e+04
# price:C(supermarket)[T.supermarket-C]                          5539.4772   2825.258      1.961      0.050       2.073    1.11e+04
# price:C(variant)[T.light]                                     -2.893e+04   5019.115     -5.765      0.000   -3.88e+04   -1.91e+04
# price:C(variant)[T.standard]                                  -3.786e+04   4199.665     -9.016      0.000   -4.61e+04   -2.96e+04
# price:C(pack_size)[T.351 - 500 GR]                            -1.132e+04   1781.614     -6.353      0.000   -1.48e+04   -7826.792
# price:C(pack_size)[T.501 - 700 GR]                             2.904e+04   2698.789     10.760      0.000    2.38e+04    3.43e+04
# price:C(pack_size)[T.701 - 1000 GR]                           -2.813e+04   5158.673     -5.453      0.000   -3.82e+04    -1.8e+04
# ar.L1                                                            -0.7702      0.035    -22.325      0.000      -0.838      -0.703
# ar.L2                                                            -0.5179      0.040    -12.794      0.000      -0.597      -0.439
# ar.L3                                                            -0.2324      0.035     -6.648      0.000      -0.301      -0.164
# ar.S.L12                                                         -0.4917      0.026    -19.157      0.000      -0.542      -0.441
# sigma2                                                           1.3e+09      0.668   1.95e+09      0.000     1.3e+09     1.3e+09
# ===================================================================================
# Ljung-Box (L1) (Q):                   1.12   Jarque-Bera (JB):               700.33
# Prob(Q):                              0.29   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.16   Skew:                             0.42
# Prob(H) (two-sided):                  0.16   Kurtosis:                         6.83
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 7.69e+24. Standard errors may be unstable.
